# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Tree
from arrangement_combination import  to_dict,to_str,regenerate

# %%
elements = ["A", "A", "B", "C", "D"]
width = 2**len(elements) * 94
height = 1000
elements = ["{}:{}".format(i, e) for i, e in enumerate(elements)]
size = len(elements)
rs = to_dict(elements)
rs = {"root": rs}
# print(rs)
reshape_data = regenerate(rs)
# print(reshape_data)
tree = (
    Tree(init_opts=opts.InitOpts(width="1000px".format(width), height="3000px"))
    .add("", reshape_data, initial_tree_depth=5, symbol_size=[5, 5],
         # orient="TB",
         # label_opts=opts.LabelOpts(
         #     position="bottom",
         #     horizontal_align="right",
         #     vertical_align="middle",
         # ),
         label_opts=opts.LabelOpts(
             margin=0,
             position="inner",
             horizontal_align="left",
             vertical_align="middle",
         ),
         )
    .set_global_opts(title_opts=opts.TitleOpts(title="排列"))
)
tree.render("./tree.html")
array_list = to_str(rs)
unique_array_list = set([tuple([y[-1] for y in x[5:].split("_")]) for x in array_list])
print("重复的序列有{}个，不重复的序列有{}个".format(len(array_list), len(unique_array_list)))
print("不重复的序列是：\r\n{}".format('\r\n'.join([','.join(x) for x in unique_array_list])))
# Out:
# {'root': {'0:A': {'1:A': {'2:B': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'2:B': '4:D', '4:D': '2:B'}, '4:D': {'2:B': '3:C', '3:C': '2:B'}}, '2:B': {'1:A': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'1:A': '4:D', '4:D': '1:A'}, '4:D': {'1:A': '3:C', '3:C': '1:A'}}, '3:C': {'1:A': {'2:B': '4:D', '4:D': '2:B'}, '2:B': {'1:A': '4:D', '4:D': '1:A'}, '4:D': {'1:A': '2:B', '2:B': '1:A'}}, '4:D': {'1:A': {'2:B': '3:C', '3:C': '2:B'}, '2:B': {'1:A': '3:C', '3:C': '1:A'}, '3:C': {'1:A': '2:B', '2:B': '1:A'}}}, '1:A': {'0:A': {'2:B': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'2:B': '4:D', '4:D': '2:B'}, '4:D': {'2:B': '3:C', '3:C': '2:B'}}, '2:B': {'0:A': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'0:A': '4:D', '4:D': '0:A'}, '4:D': {'0:A': '3:C', '3:C': '0:A'}}, '3:C': {'0:A': {'2:B': '4:D', '4:D': '2:B'}, '2:B': {'0:A': '4:D', '4:D': '0:A'}, '4:D': {'0:A': '2:B', '2:B': '0:A'}}, '4:D': {'0:A': {'2:B': '3:C', '3:C': '2:B'}, '2:B': {'0:A': '3:C', '3:C': '0:A'}, '3:C': {'0:A': '2:B', '2:B': '0:A'}}}, '2:B': {'0:A': {'1:A': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'1:A': '4:D', '4:D': '1:A'}, '4:D': {'1:A': '3:C', '3:C': '1:A'}}, '1:A': {'0:A': {'3:C': '4:D', '4:D': '3:C'}, '3:C': {'0:A': '4:D', '4:D': '0:A'}, '4:D': {'0:A': '3:C', '3:C': '0:A'}}, '3:C': {'0:A': {'1:A': '4:D', '4:D': '1:A'}, '1:A': {'0:A': '4:D', '4:D': '0:A'}, '4:D': {'0:A': '1:A', '1:A': '0:A'}}, '4:D': {'0:A': {'1:A': '3:C', '3:C': '1:A'}, '1:A': {'0:A': '3:C', '3:C': '0:A'}, '3:C': {'0:A': '1:A', '1:A': '0:A'}}}, '3:C': {'0:A': {'1:A': {'2:B': '4:D', '4:D': '2:B'}, '2:B': {'1:A': '4:D', '4:D': '1:A'}, '4:D': {'1
'2:B'}], 'name': '3:C'}], 'name': '4:D'}], 'name': '0:A'}, {'children': [{'children': [{'children': [{'name': '4:D'}], 'name': '3:C'}, {'children': [{'name': '3:C'}], 'name': '4:D'}], 'name': '0:A'}, {'children': [{'children': [{'name': '4:D'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '4:D'}], 'name': '3:C'}, {'children': [{'children': [{'name': '3:C'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '3:C'}], 'name': '4:D'}], 'name': '2:B'}, {'children': [{'children': [{'children': [{'name': '4:D'}], 'name': '2:B'}, {'children': [{'name': '2:B'}], 'name': '4:D'}], 'name': '0:A'}, {'children': [{'children': [{'name': '4:D'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '4:D'}], 'name': '2:B'}, {'children': [{'children': [{'name': '2:B'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '2:B'}], 'name': '4:D'}], 'name': '3:C'}, {'children': [{'children': [{'children': [{'name': '3:C'}], 'name': '2:B'}, {'children': [{'name': '2:B'}], 'name': '3:C'}], 'name': '0:A'}, {'children': [{'children': [{'name': '3:C'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '3:C'}], 'name': '2:B'}, {'children': [{'children': [{'name': '2:B'}], 'name': '0:A'}, {'children': [{'name': '0:A'}], 'name': '2:B'}], 'name': '3:C'}], 'name': '4:D'}], 'name': '1:A'}, {'children': [{'children': [{'children': [{'children': [{'name': '4:D'}], 'name': '3:C'}, {'children': [{'name': '3:C'}], 'name': '4:D'}], 'name': '1:A'}, {'children': [{'children': [{'name': '4:D'}], 'name': '1:A'}, {'children': [{'name': '1:A'}], 'name': '4:D'}], 'name': '3:C'}, {'children': [{'children': [{'name': '3:C'}], 'name': '1:A'}, {'children': [{'name': '1:A'}], 'name': '3:C'}], 'name': '4:D'}], 'name': '0:A'}, {'children': [{'children': [{'children': [{'name': '4:D'}], 'name': '3:C'}, {'children': [{'name': '3:C'}], 'name': '4:D'}], 'name': '0:A'}, {'children': [{'children': [{'name': '4:D'}], 'name': '0:A'} ...
# 重复的序列有120个，不重复的序列有60个
# 不重复的序列是：
# D,A,A,B,C
# D,A,B,A,C
# C,A,A,B,D
# C,A,B,A,D
# C,B,A,D,A
# C,B,D,A,A
# D,C,A,A,B
# B,A,A,D,C
# B,A,D,A,C
# A,B,C,D,A
# A,B,D,C,A
# C,B,A,A,D
# B,C,A,D,A
# B,C,D,A,A
# A,B,A,C,D
# A,B,C,A,D
# B,D,A,A,C
# B,A,C,D,A
# B,A,D,C,A
# A,B,D,A,C
# A,B,A,D,C
# A,D,B,C,A
# A,D,C,B,A
# C,A,A,D,B
# C,A,D,A,B
# D,A,A,C,B
# D,A,C,A,B
# D,B,A,A,C
# A,A,C,D,B
# A,A,D,C,B
# A,A,D,B,C
# A,A,B,D,C
# A,C,A,B,D
# A,C,B,A,D
# A,A,C,B,D
# A,A,B,C,D
# A,D,A,C,B
# A,D,C,A,B
# A,C,A,D,B
# A,C,D,A,B
# D,C,A,B,A
# D,C,B,A,A
# B,A,A,C,D
# B,A,C,A,D
# D,B,C,A,A
# A,C,D,B,A
# A,C,B,D,A
# B,C,A,A,D
# C,D,A,B,A
# C,D,B,A,A
# A,D,A,B,C
# A,D,B,A,C
# C,A,B,D,A
# C,A,D,B,A
# D,A,B,C,A
# D,A,C,B,A
# B,D,A,C,A
# B,D,C,A,A
# C,D,A,A,B
# D,B,A,C,A

# %%
# Out:
# '/home/jovyan/tree.html'
